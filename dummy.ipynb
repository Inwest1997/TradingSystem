# %%
from src.data_loader import *
from src.ticker_selection import *
from src.index import *

# %%
df = DataGenerator('db').data_search('GOOG')
# Out:
# DB에서 데이터 불러오기 성공

# %%
class Trading:
    def __init(self, ticker, signal, amount, units = 0):
        self.ticker = ticker
        self.initial_amount = amount
        self.amount = amount
        # self.ftc = ftc
        # self.ptc = ptc
        self.units = units
        self.position = 0
        self.trades = 0
        self.signal = signal
        self.get_data()
    
    def get_data(self):


        pass
    def long():
        
        pass
    def short():
        pass
    def maintain():
        pass

# %%
ss = stock_standard(df)

# %%
ss.calculator(6)['Standard'].value_counts()
# Out:
# 0    4346
# 1     117
# Name: Standard, dtype: int64

# %%
df.shift()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Datetime
# 2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...                ...         ...         ...         ...         ...
# 2022-10-24  102.089996  103.099998  100.300003  102.970001  102.970001
# 2022-10-25  103.300003  105.099899  103.019997  104.930000  104.930000
# 2022-10-25  103.300003  105.099998  103.019997  104.930000  104.930000
# 2022-10-26   96.760002   98.540001   94.570000   94.820000   94.820000
# 2022-10-27   94.309998   95.169998   91.900002   92.599998   92.599998
#
#                  Volume
# Datetime
# 2004-08-19  897427216.0
# 2004-08-20  458857488.0
# ...

# %%
df['Adj Close']-df['Adj Close'].shift(1)
# Out:
# Datetime
# 2004-08-19          NaN
# 2004-08-20     0.198506
# 2004-08-23     0.027148
# 2004-08-24    -0.112827
# 2004-08-25     0.028144
#                 ...
# 2022-10-24     1.489998
# 2022-10-25     1.959999
# 2022-10-25     0.000000
# 2022-10-26   -10.110001
# 2022-10-27    -2.220001
# Name: Adj Close, Length: 4582, dtype: float64

# %%
pdi = df['High']-df['High'].shift(1)
mdi = df['Low']-df['Low'].shift(1)
adx = np.abs(pdi-mdi)/pdi*mdi*100

# %%
fig = plt.figure(figsize=(20,6)) ## 캔버스 생성
fig.set_facecolor('white')
ax1 = fig.add_subplot() ## axes 생성

color1 = 'b'
ax1.plot(ma['SIGNAL'].iloc[-400:], color=color1)
ax1.set_xlabel('x')
ax1.set_ylabel('SIGNAL', color=color1)
ax1.tick_params(axis='y', labelcolor=color1)
 
color2 = 'r'
ax2 = ax1.twinx()
ax2.plot(ma['SMA(5)'].iloc[-400:], color=color2)
ax2.set_ylabel('MA5', color=color2)
ax2.tick_params(axis='y', labelcolor=color2)
 
color3 = 'g'
ax3 = ax1.twinx()
ax3.plot(ma['SMA(20)'].iloc[-400:], color=color3)
ax3.set_ylabel('MA20', color=color3)
ax3.tick_params(axis='y', labelcolor=color3)

color4 = 'c'
ax4 = ax1.twinx()
ax4.plot(ma['SMA(60)'].iloc[-400:], color=color4)
ax4.set_ylabel('MA60', color=color4)
ax4.tick_params(axis='y', labelcolor=color4)

color5 = 'y'
ax5 = ax1.twinx()
ax5.plot(ma['SMA(5)'].iloc[-400:], color=color5)
ax5.set_ylabel('MA5', color=color5)
ax5.tick_params(axis='y', labelcolor=color5)

color6 = 'k'
ax6 = ax1.twinx()
ax6.plot(ma['Adj Close'].iloc[-400:], color=color6)
ax6.set_xlabel('x')
ax6.set_ylabel('Close', color=color6)
ax6.tick_params(axis='y', labelcolor=color6)

plt.show()

# %%
from src.strategy import *
from src.data_loader import *
